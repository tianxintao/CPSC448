# %% [markdown]
# # Grid World

# %%
import numpy as np
from grid_world import *
# %matplotlib inline

# %% [markdown]
# <br>
# ## Introduction to Grid World game

# %% [markdown]
# ![image.png](attachment:image.png)
# **copied from Reinforcement Learning: An Introduction**

# %% [markdown]
# <br>
# ## Let's see how the value of each state changes!

# %%
game = GridWorld()

# %%
game.WORLD_SIZE
# Out:
# 5

# %%
game.ACTIONS
# Out:
# [array([ 0, -1]), array([-1,  0]), array([0, 1]), array([1, 0])]

# %%
game.DISCOUNT
# Out:
# 0.9

# %%
game.A_POS
# Out:
# [0, 1]

# %%
game.B_POS
# Out:
# [0, 3]

# %% [markdown]
# <br>
# ## Update value of each state using bellman equation

# %% [markdown]
# Bellman equation is defined as follows:
# \begin{equation*}
# v_\pi = \sum_{a} \pi(a|s) \sum_{s',r}p(s',r|s,a)[r + \gamma v_\pi(s')]
# \end{equation*}
# --rl book(3.14)

# %% [markdown]
# In the case of GridWorld, p(s′,r|s,a) is always 1, when we are under state s and taking action a. Since the rule of game is deterministic, taking a specific action under a specific state will only lead to one state s' and gain reward r.
# Then the equation becomes:
# \begin{equation*}
# v_\pi = \sum_{a} \pi(a|s) [r + \gamma v_\pi(s')]
# \end{equation*}
# <br>
# This equation is the one used in function **ValueUpdateBellman()**, or **figure_3_2()** in the original code

# %%
game.ValueUpdateBellman()
# Out:
# Value function converges after 16 loops

# %% [markdown]
# _Read from buttom to top, the buttom one is the first value update and the top one is the last value update_
# ![figure_1_16.png](attachment:figure_1_16.png)![figure_1_15.png](attachment:figure_1_15.png)![figure_1_14.png](attachment:figure_1_14.png)![figure_1_13.png](attachment:figure_1_13.png)![figure_1_12.png](attachment:figure_1_12.png)![figure_1_11.png](attachment:figure_1_11.png)![figure_1_10.png](attachment:figure_1_10.png)![figure_1_9.png](attachment:figure_1_9.png)![figure_1_8.png](attachment:figure_1_8.png)![figure_1_7.png](attachment:figure_1_7.png)![figure_1_6.png](attachment:figure_1_6.png)![figure_1_5.png](attachment:figure_1_5.png)![figure_1_4.png](attachment:figure_1_4.png)![figure_1_3.png](attachment:figure_1_3.png)![figure_1_2.png](attachment:figure_1_2.png)![figure_1_1.png](attachment:figure_1_1.png)

# %% [markdown]
# ## Optimal Value Functions for Grid World

# %% [markdown]
# \begin{equation*}
# v_* = \max_{a} \sum_{s',r} p(s',r|s,a) [r + \gamma v_*]
# \end{equation*}
# <br>
# p(s',r|s,a) is always 1 as the environment is deterministic.

# %%
game.OptimalValueUpdate()
# Out:
# Optimal value function is obtained after 58 loops

# %% [markdown]
# _Read from buttom to top, the buttom one is the first value update and the top one is the last value update_
# ![figure_2_58.png](attachment:figure_2_58.png)![figure_2_57.png](attachment:figure_2_57.png)![figure_2_56.png](attachment:figure_2_56.png)![figure_2_55.png](attachment:figure_2_55.png)![figure_2_54.png](attachment:figure_2_54.png)![figure_2_53.png](attachment:figure_2_53.png)![figure_2_46.png](attachment:figure_2_46.png)![figure_2_45.png](attachment:figure_2_45.png)![figure_2_44.png](attachment:figure_2_44.png)![figure_2_43.png](attachment:figure_2_43.png)![figure_2_42.png](attachment:figure_2_42.png)![figure_2_41.png](attachment:figure_2_41.png)![figure_2_40.png](attachment:figure_2_40.png)![figure_2_39.png](attachment:figure_2_39.png)![figure_2_38.png](attachment:figure_2_38.png)![figure_2_31.png](attachment:figure_2_31.png)![figure_2_30.png](attachment:figure_2_30.png)![figure_2_29.png](attachment:figure_2_29.png)![figure_2_28.png](attachment:figure_2_28.png)![figure_2_27.png](attachment:figure_2_27.png)![figure_2_26.png](attachment:figure_2_26.png)![figure_2_25.png](attachment:figure_2_25.png)![figure_2_24.png](attachment:figure_2_24.png)![figure_2_23.png](attachment:figure_2_23.png)![figure_2_22.png](attachment:figure_2_22.png)![figure_2_20.png](attachment:figure_2_20.png)![figure_2_19.png](attachment:figure_2_19.png)![figure_2_18.png](attachment:figure_2_18.png)![figure_2_11.png](attachment:figure_2_11.png)![figure_2_10.png](attachment:figure_2_10.png)![figure_2_9.png](attachment:figure_2_9.png)![figure_2_8.png](attachment:figure_2_8.png)![figure_2_2.png](attachment:figure_2_2.png)![figure_2_1.png](attachment:figure_2_1.png)
#
# The value function of optimal policy does not contain any negative value because the optimal policy will not tend to go out of boundary

# %% [markdown]
# **Question: It seems that optimal value function is taking greedy move at each step. Would this be a problem as it doesn't explore?**

# %% [markdown]
# ## Try Different Discount Rate

# %% [markdown]
# #### Try value update function####

# %%
# see what will happen if discount rate is 1
game2 = GridWorld(DISCOUNT = 1)
game2.ValueUpdateBellman()
# basically the value function does not converge, as the very last terms of the infinite sum will not diminish
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6d1b62e7f06b> in <module>()
#       1 # see what will happen if discount rate is 1
#       2 game2 = GridWorld(DISCOUNT = 1)
# ----> 3 game2.ValueUpdateBellman()
#       4 # basically the value function does not converge, as the very last terms of the infinite sum will not diminish
#
# ~\Desktop\CPSC 448\grid-world\grid_world.py in ValueUpdateBellman(self)
#      92                 for j in range(0,self.WORLD_SIZE):
#      93                     for action in self.ACTIONS:
# ---> 94                         (next_i, next_j), reward = self.step([i, j], action)
#      95                         # bellman equation
#      96                         new_value[i, j] += self.ACTION_PROB * (reward + self.DISCOUNT * value[next_i, next_j])
#
# KeyboardInterrupt:

# %%
# see what will happen if discount rate is 0.9
game2 = GridWorld(DISCOUNT = 0.9)
game2.ValueUpdateBellman()
# Out:
# Value function converges after 16 loops

# %%
game2 = GridWorld(DISCOUNT=0.5)
game2.ValueUpdateBellman()
# Out:
# Value function converges after 7 loops

# %% [markdown]
# #### Try solving optimal Bellman equation####

# %%
game3 = GridWorld(DISCOUNT=0.9)
game3.OptimalValueUpdate()
# Out:
# Optimal value function is obtained after 58 loops

# %%
game3 = GridWorld(DISCOUNT=0.999)
game3.OptimalValueUpdate()
# Out:
# Optimal value function is obtained after 5993 loops

# %%
game3 = GridWorld(DISCOUNT=0.5)
game3.OptimalValueUpdate()
# Out:
# Optimal value function is obtained after 10 loops

# %% [markdown]
# Basically, it seems that when discount rate is 0.9 or 0.999, the value function of each state shows the exact same pattern. While the discount rate is adjusted to 0.5, the pattern changes. However, the smaller discount rate help the value function converges

# %% [markdown]
# <br>
# ## Try value update on a different policy##

# %% [markdown]
# Try a new policy:
# 1. When for the state that on the boundary, set the probability of walking out of the boundary to be 0.1
# 2. For the rest state, the probablity is equal on all directions

# %%
game4 = GridWorld(outProb=0.1)
game4.ValueUpdateBellman()
# Out:
# Value function converges after 21 loops

# %%
# compare with the original policy
game4 = GridWorld()
game4.ValueUpdateBellman()
# Out:
# Value function converges after 16 loops

# %% [markdown]
# *The general value of each state increases, but the pattern of those values remains unchanged*
